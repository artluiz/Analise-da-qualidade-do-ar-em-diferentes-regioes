# %%
body_part = input("Body Part: ")
verb = input("Verbo: ")
adj1 = input("Adjetivo: ")
adj2 = input("Adjetivo: ")
adj3 = input("Adjetivo: ")
adj4 = input("Adjetivo: ")
adj5 = input("Adjetivo: ")
noun1 = input("Nome: ")
noun2 = input("Nome: ")
noun_plural_1 = input("Nome (plural): ")
noun_plural_2 = input("Nome (plural): ")

madlib = f"Eu amo programar porque é {adj1}! A jornada para ser tornar um \
bom programador começa com esperança em sua mente e um sonho em seu/sua {body_part}. Com sangue, \
suor, e {noun_plural_1}, nunca terminará. Sim, uma vez que você aprenda {verb}, se torna \
uma parte da sua vida e você pode se tornar um super {adj2} hacker. Conhecimento de programação \
te deixa tomar controle de seu/sua {noun1}. Você pode criar seu próprio(s) {noun_plural_2}, tudo \
de desenvolvimento software {adj3} a analisar dados e fazer predições sobre {noun2}. Você pode \
criar seu Jarvis e deixar ele mais {adj4}. Espero que você comece sua jornada {adj5} \
codando comigo :)"
    
print(madlib)
# Out:
# Body Part: pau
# Verb: comer
# Adjetivo: incrível
# Adjetivo: maravilhos
# Adjetivo: fantástico
# Adjetivo: lindo
# Adjetivo: super
# Nome: dd
# Nome: ff
# Nome (plural): lágrimas
# Nome (plural): mundos
# Eu amo programar porque é incrível! A jornada para ser tornar um bom programador começa com esperança em sua mente e um sonho em seu/sua pau. Com sangue, suor, e lágrimas, nunca terminará. Sim, uma vez que você aprenda comer, se torna uma parte da sua vida e você pode se tornar um super maravilhos hacker. Conhecimento de programação te deixa tomar controle de seu/sua dd. Você pode criar seu próprio mundos, tudo de desenvolvimento software fantástico a analisar dados e fazer predições sobre ff. Você pode criar seu Jarvis e deixar ele mais lindo. Espero que você comece sua jornada super codando comigo :)
